# %% [markdown]
# # Do Interictal DischargesAffect Functional Connectivity
#
# author: Jeni Stiso (jeni.stiso@gmail.com)
#
# words

# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.anova import AnovaRM
#import pingouin as pg

# %matplotlib inline
sns.set_context('poster')
sns.set_style("whitegrid")

# %%
# directories - point this at you RAM data
RAM_dir = '/Volumes/bassett-data/Jeni/RAM/'

# load data
net_data = pd.read_csv(RAM_dir + 'group_analysis/network_stats.csv', index_col=0)
node_data = pd.read_csv(RAM_dir + 'group_analysis/node_stats.csv', index_col=0)

# %% [markdown]
# Check the data

# %%
net_data.head(10)
# Out:
#    band_measure  soz  n_tp  str_beta_bin  str_beta_num fc_measure   band  \
# 1     alpha_aec    0   480     -0.132493      0.183166        aec  alpha
# 2     alpha_aec    1   480      0.032038      0.100710        aec  alpha
# 3     alpha_coh    0   480     -0.048947      0.081327        coh  alpha
# 4     alpha_coh    1   480     -0.087044      0.102519        coh  alpha
# 5     alpha_plv    0   480     -0.060697      0.108915        plv  alpha
# 6     alpha_plv    1   480     -0.031695      0.113413        plv  alpha
# 7      beta_aec    0   480     -0.205420      0.254162        aec   beta
# 8      beta_aec    1   480     -0.050697      0.152268        aec   beta
# 9      beta_coh    0   480     -0.168194      0.212216        coh   beta
# 10     beta_coh    1   480      0.022984     -0.024290        coh   beta
#
#       subj hand  age gender  race
# 1   R1284N    L   32      F   1.0
# 2   R1284N    L   32      F   1.0
# 3   R1284N    L   32      F   1.0
# 4   R1284N    L   32      F   1.0
# 5   R1284N    L   32      F   1.0
# 6   R1284N    L   32      F   1.0
# 7   R1284N    L   32      F   1.0
# 8   R1284N    L   32      F   1.0
# 9   R1284N    L   32      F   1.0
# 10  R1284N    L   32      F   1.0

# %%
net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5888 entries, 1 to 5888
# Data columns (total 12 columns):
# band_measure    5888 non-null object
# soz             5888 non-null int64
# n_tp            5888 non-null int64
# str_beta_bin    5888 non-null float64
# str_beta_num    5664 non-null float64
# fc_measure      5888 non-null object
# band            5888 non-null object
# subj            5888 non-null object
# hand            5776 non-null object
# age             5888 non-null int64
# gender          5888 non-null object
# race            5648 non-null float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 598.0+ KB

# %%
net_data.describe()
# Out:
#                soz         n_tp  str_beta_bin  str_beta_num          age  \
# count  5888.000000  5888.000000   5888.000000   5664.000000  5888.000000
# mean      0.415761  1115.635870     -0.030753      0.086569    35.891304
# std       0.492895  1424.733241      0.297893      0.342458    11.889949
# min       0.000000    15.000000     -6.226156     -4.610045     0.000000
# 25%       0.000000   161.000000     -0.100334     -0.046166    26.750000
# 50%       0.000000   552.000000     -0.023977      0.038506    34.000000
# 75%       1.000000  1353.000000      0.045105      0.187077    44.000000
# max       1.000000  7643.000000      4.705489      6.145538    66.000000
#
#               race
# count  5648.000000
# mean      2.906516
# std       1.211380
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       7.000000

# %%
node_data.head(10)
# Out:
#     elec  elec_in_soz  elec_has_spike     band_measure  n_tp  \
# 1   LAD1            1               0        alpha_aec    53
# 2   LAD1            1               0        alpha_coh    53
# 3   LAD1            1               0        alpha_plv    53
# 4   LAD1            1               0         beta_aec    53
# 5   LAD1            1               0         beta_coh    53
# 6   LAD1            1               0         beta_plv    53
# 7   LAD1            1               0     broadband_ar    53
# 8   LAD1            1               0  broadband_xcorr    53
# 9   LAD1            1               0        gamma_aec    53
# 10  LAD1            1               0        gamma_coh    53
#
#     str_soz_beta_bin  str_not_soz_beta_bin  str_spike_beta_bin  \
# 1          -0.051580                   NaN            0.167135
# 2           0.119115                   NaN           -0.174351
# 3           0.144776                   NaN            0.121942
# 4          -0.054380                   NaN           -0.089687
# 5           0.029213                   NaN           -0.148837
# 6           0.111729                   NaN           -0.190841
# 7           0.502957                   NaN           -0.075085
# 8           0.022616                   NaN            0.213736
# 9           0.090989                   NaN            0.233070
# 10          0.160766                   NaN           -0.114829
#
#     str_not_spike_beta_bin  tr_soz_beta_bin       ...         \
# 1                -0.118119        -0.044516       ...
# 2                 0.211381         0.032518       ...
# 3                 0.128337         0.135996       ...
# 4                -0.031627         0.007869       ...
# 5                 0.086209        -0.050310       ...
# 6                 0.205265        -0.034298       ...
# 7                 0.491475        -0.566199       ...
# 8                -0.033340         0.054303       ...
# 9                 0.021555         0.226907       ...
# 10                0.240529         0.170894       ...
#
#     str_not_spike_beta_num  fc_measure       band            region    subj  \
# 1                 0.040646         aec      alpha  inferiortemporal  R1260D
# 2                -0.103013         coh      alpha  inferiortemporal  R1260D
# 3                 0.111721         plv      alpha  inferiortemporal  R1260D
# 4                -0.040960         aec       beta  inferiortemporal  R1260D
# 5                -0.005859         coh       beta  inferiortemporal  R1260D
# 6                -0.063936         plv       beta  inferiortemporal  R1260D
# 7                -0.486275          ar  broadband  inferiortemporal  R1260D
# 8                 0.083900       xcorr  broadband  inferiortemporal  R1260D
# 9                 0.281796         aec      gamma  inferiortemporal  R1260D
# 10                0.094971         coh      gamma  inferiortemporal  R1260D
#
#    hand age gender  race str_soz_beta_num
# 1     R  57      F   2.0              NaN
# 2     R  57      F   2.0              NaN
# 3     R  57      F   2.0              NaN
# 4     R  57      F   2.0              NaN
# 5     R  57      F   2.0              NaN
# 6     R  57      F   2.0              NaN
# 7     R  57      F   2.0              NaN
# 8     R  57      F   2.0              NaN
# 9     R  57      F   2.0              NaN
# 10    R  57      F   2.0              NaN
#
# [10 rows x 22 columns]

# %%
node_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 335200 entries, 1 to 335200
# Data columns (total 22 columns):
# elec                      335200 non-null object
# elec_in_soz               335200 non-null int64
# elec_has_spike            335200 non-null int64
# band_measure              335200 non-null object
# n_tp                      335200 non-null int64
# str_soz_beta_bin          201216 non-null float64
# str_not_soz_beta_bin      184912 non-null float64
# str_spike_beta_bin        201216 non-null float64
# str_not_spike_beta_bin    175824 non-null float64
# tr_soz_beta_bin           288048 non-null float64
# str_not_soz_beta_num      262304 non-null float64
# str_spike_beta_num        288112 non-null float64
# str_not_spike_beta_num    249552 non-null float64
# fc_measure                335200 non-null object
# band                      335200 non-null object
# region                    302576 non-null object
# subj                      335200 non-null object
# hand                      335200 non-null object
# age                       335200 non-null int64
# gender                    335200 non-null object
# race                      330096 non-null float64
# str_soz_beta_num          0 non-null float64
# dtypes: float64(10), int64(4), object(8)
# memory usage: 58.8+ MB

# %%
node_data.describe()
# Out:
#          elec_in_soz  elec_has_spike           n_tp  str_soz_beta_bin  \
# count  335200.000000   335200.000000  335200.000000     201216.000000
# mean        0.087637        0.396277     729.157184         -0.003641
# std         0.282767        0.489124    1278.161518          0.248656
# min         0.000000        0.000000       1.000000         -4.603055
# 25%         0.000000        0.000000      13.000000         -0.057485
# 50%         0.000000        0.000000     103.000000         -0.003219
# 75%         0.000000        1.000000     858.000000          0.049608
# max         1.000000        1.000000    7643.000000          5.925162
#
#        str_not_soz_beta_bin  str_spike_beta_bin  str_not_spike_beta_bin  \
# count         184912.000000       201216.000000           175824.000000
# mean              -0.007000           -0.002787               -0.007418
# std                0.249188            0.248261                0.240768
# min               -5.191694           -4.784929               -5.670958
# 25%               -0.065968           -0.059506               -0.065130
# 50%               -0.007098           -0.004056               -0.007230
# 75%                0.048775            0.049904                0.047936
# max                5.836851            6.422419                4.849069
#
#        tr_soz_beta_bin  str_not_soz_beta_num  str_spike_beta_num  \
# count    288048.000000         262304.000000       288112.000000
# mean          0.087930              0.044416            0.067180
# std          19.997730             17.439900           26.640989
# min       -2854.057085          -3893.538569        -9746.145329
# 25%          -0.055619             -0.049241           -0.054149
# 50%           0.022400              0.034201            0.026421
# 75%           0.142183              0.178657            0.156186
# max        7591.485709           5341.400492         7588.131060
#
#        str_not_spike_beta_num            age           race  str_soz_beta_num
# count           249552.000000  335200.000000  330096.000000               0.0
# mean                 0.060014      36.321337       3.143280               NaN
# std                 18.671412      11.526545       1.157563               NaN
# min              -4796.581137      16.000000       1.000000               NaN
# 25%                 -0.048945      26.000000       2.000000               NaN
# 50%                  0.033195      35.000000       4.000000               NaN
# 75%                  0.175681      45.000000       4.000000               NaN
# max               4661.625337      64.000000       4.000000               NaN

# %%
sns.distplot(net_data['n_tp'], bins=30, color='steelblue')
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
net_data.subj.nunique()
# Out:
# 194

# %%
sns.distplot(net_data['age'], bins=30, color='steelblue')
mean_age = net_data['age'].mean()
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(data=net_data, x='race', )
mean_race = 4

# %%
sns.countplot(data=net_data, x='hand', )
mean_hand = 'R'

# %%
sns.jointplot(data=net_data, x='str_beta_num', y='n_tp', kind='kde' )

# %%
sns.violinplot(data=net_data, x='gender', y='str_beta_num')

# %%
# add means for null values
net_data.loc[net_data['age'].isnull(), 'age'] = mean_age
net_data.loc[net_data['race'].isnull(), 'race'] = mean_race
net_data.loc[net_data['hand'].isnull(), 'hand'] = mean_hand

# %%
net_data.dropna(inplace=True)

# %%
net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5310 entries, 1 to 5888
# Data columns (total 12 columns):
# band_measure    5310 non-null object
# soz             5310 non-null int64
# n_tp            5310 non-null int64
# str_beta_bin    5310 non-null float64
# str_beta_num    5310 non-null float64
# fc_measure      5310 non-null object
# band            5310 non-null object
# subj            5310 non-null object
# hand            5310 non-null object
# age             5310 non-null float64
# gender          5310 non-null object
# race            5310 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 539.3+ KB

# %%
# save
net_data.to_csv('/Volumes/bassett-data/Jeni/RAM/group_analysis/net_data_clean.csv')

# %%
# cut out AR until you fix the bug
net_data = net_data[net_data['fc_measure'] != 'ar']

# %% [markdown]
# ## Effects on Network Measures
#
# test if intereictal spike regularly change network strength within, or outside of the seizure onset zone (SOZ)

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=net_data, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'str_beta_bin', 'soz')
#g.map(sns.stripplot, 'band', 'str_beta_bin', 'soz',jitter=True, dodge=True,
#              alpha=.25, zorder=1, size=8)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[3].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
for ax in g.axes:
    ax.set_ylim(-2,2)
    
g.savefig("../img/net_bin.pdf")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# grand teton palette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette(sns.color_palette(colors))
g = sns.FacetGrid(data=net_data, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'str_beta_num', 'soz')
#g.map(sns.stripplot, 'band', 'str_beta_num', 'soz',jitter=True, dodge=True,
              #alpha=.25, zorder=1, size=8)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[3].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
for ax in g.axes:
    ax.set_ylim(-2,2)
    
g.savefig("../img/net_num.pdf")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Effects on Node Measures

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=node_data, col='fc_measure' ,col_wrap = 3, 
                  sharex=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.violinplot, 'band', 'str_soz_beta_bin', 'elec_in_soz', split =True, cut=True)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the violinplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=node_data, col='fc_measure', col_wrap = 3, 
                  sharex=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.violinplot, 'band', 'str_spike_beta_bin', 'elec_in_soz', split=True, cut=True)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the violinplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=node_data, col='fc_measure', col_wrap = 3, 
                  sharex=False, legend_out=True, palette = custom_palette)
g.map(sns.violinplot, 'band', 'str_not_soz_beta_bin', height=20)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the violinplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
