# %% [markdown]
# # Do Interictal DischargesAffect Functional Connectivity
#
# author: Jeni Stiso (jeni.stiso@gmail.com)
#
# words

# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.anova import AnovaRM
import palettable

# %matplotlib inline
sns.set_context('poster')
sns.set_style("whitegrid")

# %%
sns.__version__
# Out:
# '0.8.1'

# %%
# directories - point this at you RAM data
RAM_dir = '/Volumes/bassett-data/Jeni/RAM/'

# load data
net_data = pd.read_csv(RAM_dir + 'group_analysis/network_stats.csv', index_col=0)
node_data = pd.read_csv(RAM_dir + 'group_analysis/node_stats.csv', index_col=0)

# %% [markdown]
# Check the data

# %%
net_data.head(10)
# Out:
#        band_measure  n_tp  str_beta_bin  str_beta_num  str_soz_beta_bin  \
# 1         alpha_aec  2959      0.030222      0.047299         -0.030122
# 2         alpha_coh  2959      0.686053      0.169661          0.502048
# 3         alpha_plv  2959     -0.305919     -0.031635         -0.096292
# 4          beta_aec  2959      0.197348      0.127084          0.223863
# 5          beta_coh  2959      0.532604      0.108763          0.333205
# 6          beta_plv  2959     -0.569106     -0.132635         -0.498286
# 7      broadband_ar  2959     -0.212262     -0.043367          0.088227
# 8   broadband_xcorr  2959      0.744024      0.175551          0.677232
# 9         gamma_aec  2959      0.551525      0.181383          0.541972
# 10        gamma_coh  2959      0.885706      0.177162          0.801061
#
#     str_soz_beta_num  str_not_soz_beta_num  str_spike_beta_num  \
# 1           0.035529              0.047194            0.040832
# 2           0.133389              0.159991            0.123342
# 3           0.005113             -0.044402           -0.013296
# 4           0.126175              0.112472            0.136673
# 5           0.078679              0.106344            0.087107
# 6          -0.105653             -0.107412           -0.098877
# 7           0.015966             -0.044509           -0.027170
# 8           0.167624              0.136290            0.133142
# 9           0.190773              0.172853            0.203367
# 10          0.169161              0.162476            0.170817
#
#     str_not_soz_beta_bin  str_spike_beta_bin  str_not_spike_beta_bin  \
# 1               0.096775           -0.059967                0.076767
# 2               0.648635            0.489980                0.634767
# 3              -0.313929           -0.137502               -0.286458
# 4               0.190907            0.244936                0.176276
# 5               0.551918            0.354283                0.528868
# 6              -0.426904           -0.480274               -0.465054
# 7              -0.200427           -0.175085               -0.156605
# 8               0.590854            0.564793                0.644552
# 9               0.560742            0.560689                0.543900
# 10              0.776071            0.809723                0.796313
#
#    fc_measure  str_not_spike_beta_num       band    subj hand  age gender  \
# 1         aec                0.039703      alpha  R1002P    R   49      F
# 2         coh                0.161602      alpha  R1002P    R   49      F
# 3         plv               -0.031832      alpha  R1002P    R   49      F
# 4         aec                0.108880       beta  R1002P    R   49      F
# 5         coh                0.101749       beta  R1002P    R   49      F
# 6         plv               -0.112224       beta  R1002P    R   49      F
# 7          ar               -0.038021  broadband  R1002P    R   49      F
# 8       xcorr                0.153797  broadband  R1002P    R   49      F
# 9         aec                0.167388      gamma  R1002P    R   49      F
# 10        coh                0.162771      gamma  R1002P    R   49      F
#
#     race  soz
# 1      4  NaN
# 2      4  NaN
# 3      4  NaN
# 4      4  NaN
# 5      4  NaN
# 6      4  NaN
# 7      4  NaN
# 8      4  NaN
# 9      4  NaN
# 10     4  NaN

# %%
net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 1 to 48
# Data columns (total 20 columns):
# band_measure              48 non-null object
# n_tp                      48 non-null int64
# str_beta_bin              48 non-null float64
# str_beta_num              48 non-null float64
# str_soz_beta_bin          48 non-null float64
# str_soz_beta_num          48 non-null float64
# str_not_soz_beta_num      48 non-null float64
# str_spike_beta_num        48 non-null float64
# str_not_soz_beta_bin      48 non-null float64
# str_spike_beta_bin        48 non-null float64
# str_not_spike_beta_bin    48 non-null float64
# fc_measure                48 non-null object
# str_not_spike_beta_num    48 non-null float64
# band                      48 non-null object
# subj                      48 non-null object
# hand                      48 non-null object
# age                       48 non-null int64
# gender                    48 non-null object
# race                      48 non-null int64
# soz                       0 non-null float64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 7.9+ KB

# %%
net_data.describe()
# Out:
#               n_tp  str_beta_bin  str_beta_num  str_soz_beta_bin  \
# count    48.000000     48.000000     48.000000         48.000000
# mean   3847.333333     -0.097885      0.093046         -0.124357
# std    1269.587524      0.481655      0.149118          0.450703
# min    2959.000000     -1.151422     -0.243918         -1.231415
# 25%    2959.000000     -0.373040      0.001472         -0.328415
# 50%    2959.000000     -0.042744      0.058604         -0.104758
# 75%    5624.000000      0.179382      0.171133          0.092566
# max    5624.000000      0.908271      0.496674          0.870936
#
#        str_soz_beta_num  str_not_soz_beta_num  str_spike_beta_num  \
# count         48.000000             48.000000           48.000000
# mean           0.101583              0.081866            0.093381
# std            0.132104              0.135566            0.136761
# min           -0.196360             -0.183958           -0.185731
# 25%            0.021607             -0.008558            0.008145
# 50%            0.068959              0.051896            0.057543
# 75%            0.168008              0.160376            0.142083
# max            0.467320              0.439063            0.474676
#
#        str_not_soz_beta_bin  str_spike_beta_bin  str_not_spike_beta_bin  \
# count             48.000000           48.000000               48.000000
# mean              -0.075064           -0.105155               -0.085414
# std                0.437848            0.453398                0.433460
# min               -1.071541           -1.287343               -1.040911
# 25%               -0.327262           -0.331415               -0.361981
# 50%               -0.014930           -0.078949               -0.040193
# 75%                0.191113            0.162746                0.179550
# max                0.776158            0.922122                0.796313
#
#        str_not_spike_beta_num        age       race  soz
# count               48.000000  48.000000  48.000000  0.0
# mean                 0.083665  48.666667   3.000000  NaN
# std                  0.133303   0.476393   1.429179  NaN
# min                 -0.197601  48.000000   1.000000  NaN
# 25%                 -0.001552  48.000000   1.000000  NaN
# 50%                  0.062692  49.000000   4.000000  NaN
# 75%                  0.155748  49.000000   4.000000  NaN
# max                  0.418887  49.000000   4.000000  NaN

# %%
node_data.head(10)
# Out:
#     elec     band_measure  n_tp  elec_spike  elec_in_soz  str_soz_beta_bin  \
# 1   LAF1        alpha_aec  2959    0.000338            0          0.245427
# 2   LAF1        alpha_coh  2959    0.000338            0          0.099150
# 3   LAF1        alpha_plv  2959    0.000338            0         -0.115871
# 4   LAF1         beta_aec  2959    0.000338            0          0.356024
# 5   LAF1         beta_coh  2959    0.000338            0          0.188996
# 6   LAF1         beta_plv  2959    0.000338            0          0.034840
# 7   LAF1     broadband_ar  5918    0.000338            0          0.030350
# 8   LAF1  broadband_xcorr  2959    0.000338            0          0.645207
# 9   LAF1        gamma_aec  2959    0.000338            0          0.674216
# 10  LAF1        gamma_coh  2959    0.000338            0          0.328846
#
#     str_not_soz_beta_bin  str_spike_beta_bin  str_not_spike_beta_bin  \
# 1               0.395178            0.234782                0.411157
# 2               0.228006            0.095015                0.230207
# 3              -0.157034           -0.142438               -0.163393
# 4               0.566772            0.389964                0.533014
# 5               0.021726            0.155498                0.027849
# 6              -0.103331            0.013090               -0.079578
# 7              -0.225221           -0.167947               -0.209146
# 8               0.660039            0.489511                0.728898
# 9               0.684939            0.669129                0.685830
# 10              0.247436            0.336688                0.276041
#
#     str_beta_bin  ...        band        region        x        y          z  \
# 1       0.392714  ...       alpha  temporalpole -31.5187  19.8411 -50.566007
# 2       0.230056  ...       alpha  temporalpole -31.5187  19.8411 -50.566007
# 3      -0.182803  ...       alpha  temporalpole -31.5187  19.8411 -50.566007
# 4       0.553441  ...        beta  temporalpole -31.5187  19.8411 -50.566007
# 5       0.055720  ...        beta  temporalpole -31.5187  19.8411 -50.566007
# 6      -0.053199  ...        beta  temporalpole -31.5187  19.8411 -50.566007
# 7      -0.252269  ...   broadband  temporalpole -31.5187  19.8411 -50.566007
# 8       0.795072  ...   broadband  temporalpole -31.5187  19.8411 -50.566007
# 9       0.697593  ...       gamma  temporalpole -31.5187  19.8411 -50.566007
# 10      0.372253  ...       gamma  temporalpole -31.5187  19.8411 -50.566007
#
#       subj hand age  gender  race
# 1   R1002P    R  49       F     4
# 2   R1002P    R  49       F     4
# 3   R1002P    R  49       F     4
# 4   R1002P    R  49       F     4
# 5   R1002P    R  49       F     4
# 6   R1002P    R  49       F     4
# 7   R1002P    R  49       F     4
# 8   R1002P    R  49       F     4
# 9   R1002P    R  49       F     4
# 10  R1002P    R  49       F     4
#
# [10 rows x 26 columns]

# %%
node_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3680 entries, 1 to 3680
# Data columns (total 26 columns):
# elec                      3680 non-null object
# band_measure              3680 non-null object
# n_tp                      3680 non-null int64
# elec_spike                3680 non-null float64
# elec_in_soz               3680 non-null int64
# str_soz_beta_bin          3680 non-null float64
# str_not_soz_beta_bin      3022 non-null float64
# str_spike_beta_bin        3680 non-null float64
# str_not_spike_beta_bin    3176 non-null float64
# str_beta_bin              3680 non-null float64
# str_soz_beta_num          3680 non-null float64
# str_not_soz_beta_num      3022 non-null float64
# str_spike_beta_num        3680 non-null float64
# str_beta_num              3680 non-null float64
# str_not_spike_beta_num    3176 non-null float64
# fc_measure                3680 non-null object
# band                      3680 non-null object
# region                    3008 non-null object
# x                         3680 non-null float64
# y                         3680 non-null float64
# z                         3680 non-null float64
# subj                      3680 non-null object
# hand                      3680 non-null object
# age                       3680 non-null int64
# gender                    3680 non-null object
# race                      3680 non-null int64
# dtypes: float64(14), int64(4), object(8)
# memory usage: 776.2+ KB

# %%
node_data.describe()
# Out:
#                n_tp   elec_spike  elec_in_soz  str_soz_beta_bin  \
# count   3680.000000  3680.000000  3680.000000       3680.000000
# mean    3615.969293     0.008272     0.204348         -0.029668
# std     1726.732059     0.015191     0.403279          0.318843
# min      578.000000     0.000000     0.000000         -1.933029
# 25%     2675.000000     0.001014     0.000000         -0.187602
# 50%     2959.000000     0.002806     0.000000         -0.017798
# 75%     5351.000000     0.009574     0.000000          0.139367
# max    11248.000000     0.100277     1.000000          2.043454
#
#        str_not_soz_beta_bin  str_spike_beta_bin  str_not_spike_beta_bin  \
# count           3022.000000         3680.000000             3176.000000
# mean              -0.021031           -0.022699               -0.024775
# std                0.344136            0.291966                0.354874
# min               -2.363019           -1.625180               -2.297324
# 25%               -0.224480           -0.173296               -0.214899
# 50%               -0.003480           -0.015411               -0.015035
# 75%                0.171007            0.141387                0.178333
# max                2.338760            1.637911                2.324423
#
#        str_beta_bin  str_soz_beta_num  str_not_soz_beta_num  \
# count   3680.000000       3680.000000           3022.000000
# mean      -0.031387          0.058661              0.056001
# std        0.370563          0.096823              0.108236
# min       -2.257024         -0.294150             -0.244735
# 25%       -0.246823         -0.002058             -0.014942
# 50%       -0.017568          0.038740              0.032429
# 75%        0.168249          0.095105              0.103536
# max        2.332472          0.797508              0.683598
#
#        str_spike_beta_num  str_beta_num  str_not_spike_beta_num            x  \
# count         3680.000000   3680.000000             3176.000000  3680.000000
# mean             0.047920      0.067186                0.060515     0.041156
# std              0.090997      0.114078                0.110598    44.196568
# min             -0.237052     -0.281374               -0.261874   -68.930700
# 25%             -0.013465     -0.009509               -0.012838   -40.312400
# 50%              0.032119      0.044079                0.036560   -17.837300
# 75%              0.086279      0.114610                0.108474    41.301800
# max              0.899898      0.687430                0.670387    71.090500
#
#                  y            z          age         race
# count  3680.000000  3680.000000  3680.000000  3680.000000
# mean     -2.573406    -5.834771    48.626087     2.878261
# std      35.933415    34.155713     0.483907     1.451720
# min     -86.697600   -51.099583    48.000000     1.000000
# 25%     -22.008100   -27.059267    48.000000     1.000000
# 50%      -7.487885   -19.633733    49.000000     4.000000
# 75%      22.952200     7.882405    49.000000     4.000000
# max      69.728700    75.873164    49.000000     4.000000

# %%
sns.distplot(net_data['n_tp'], bins=30, color='steelblue')
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
net_data.subj.nunique()
# Out:
# 2

# %%
sns.distplot(net_data['age'], bins=30, color='steelblue')
mean_age = net_data['age'].mean()
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(data=net_data, x='race', )
mean_race = 4

# %%
sns.countplot(data=net_data, x='hand', )
mean_hand = 'R'

# %%
sns.jointplot(data=net_data, x='str_beta_num', y='n_tp', kind='kde' )

# %%
sns.violinplot(data=net_data, x='gender', y='str_beta_num', cut=True)

# %%
# add means for null values
net_data.loc[net_data['age'].isnull(), 'age'] = mean_age
net_data.loc[net_data['race'].isnull(), 'race'] = mean_race
net_data.loc[net_data['hand'].isnull(), 'hand'] = mean_hand

# same for node data
node_data.loc[node_data['age'].isnull(), 'age'] = mean_age
node_data.loc[node_data['race'].isnull(), 'race'] = mean_race
node_data.loc[node_data['hand'].isnull(), 'hand'] = mean_hand

# %%
net_data.dropna(inplace=True)
#net_data['soz'] = net_data['soz'].astype('category')
net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7172 entries, 1 to 8096
# Data columns (total 12 columns):
# band_measure    7172 non-null object
# soz             7172 non-null category
# n_tp            7172 non-null int64
# str_beta_bin    7172 non-null float64
# str_beta_num    7172 non-null float64
# fc_measure      7172 non-null object
# band            7172 non-null object
# subj            7172 non-null object
# hand            7172 non-null object
# age             7172 non-null float64
# gender          7172 non-null object
# race            7172 non-null float64
# dtypes: category(1), float64(4), int64(1), object(6)
# memory usage: 679.5+ KB

# %%
net_data.dropna(inplace=True)
node_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209280 entries, 1 to 209280
# Data columns (total 26 columns):
# elec                      209280 non-null object
# band_measure              209280 non-null object
# n_tp                      209280 non-null int64
# elec_spike                209280 non-null float64
# elec_in_soz               209280 non-null int64
# str_soz_beta_bin          207728 non-null float64
# str_not_soz_beta_bin      192284 non-null float64
# str_spike_beta_bin        208608 non-null float64
# str_not_spike_beta_bin    171530 non-null float64
# str_beta_bin              208608 non-null float64
# str_soz_beta_num          207728 non-null float64
# str_not_soz_beta_num      192284 non-null float64
# str_spike_beta_num        208608 non-null float64
# str_beta_num              208608 non-null float64
# str_not_spike_beta_num    171530 non-null float64
# fc_measure                209280 non-null object
# band                      209280 non-null object
# region                    192448 non-null object
# x                         209280 non-null float64
# y                         209280 non-null float64
# z                         209280 non-null float64
# subj                      209280 non-null object
# hand                      209280 non-null object
# age                       209280 non-null float64
# gender                    209280 non-null object
# race                      209280 non-null float64
# dtypes: float64(16), int64(2), object(8)
# memory usage: 43.1+ MB

# %%
node_data.dropna(axis=0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150392 entries, 7 to 209272
# Data columns (total 26 columns):
# elec                      150392 non-null object
# band_measure              150392 non-null object
# n_tp                      150392 non-null int64
# elec_spike                150392 non-null float64
# elec_in_soz               150392 non-null int64
# str_soz_beta_bin          150392 non-null float64
# str_not_soz_beta_bin      150392 non-null float64
# str_spike_beta_bin        150392 non-null float64
# str_not_spike_beta_bin    150392 non-null float64
# str_beta_bin              150392 non-null float64
# str_soz_beta_num          150392 non-null float64
# str_not_soz_beta_num      150392 non-null float64
# str_spike_beta_num        150392 non-null float64
# str_beta_num              150392 non-null float64
# str_not_spike_beta_num    150392 non-null float64
# fc_measure                150392 non-null object
# band                      150392 non-null object
# region                    150392 non-null object
# x                         150392 non-null float64
# y                         150392 non-null float64
# z                         150392 non-null float64
# subj                      150392 non-null object
# hand                      150392 non-null object
# age                       150392 non-null float64
# gender                    150392 non-null object
# race                      150392 non-null float64
# dtypes: float64(16), int64(2), object(8)
# memory usage: 31.0+ MB

# %%
# save
net_data.to_csv('/Volumes/bassett-data/Jeni/RAM/group_analysis/net_data_clean.csv')

# %% [markdown]
# ## Effects on Network Measures
#
# test if intereictal spike regularly change network strength.

# %%
# color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set2')
    
plt.figure(figsize=(10,10))
sns.boxplot( data=net_data, x="band", y='str_beta_bin', hue='fc_measure')
sns.stripplot( data=net_data, x="band", y='str_beta_bin',hue='fc_measure',color='black',jitter=True, dodge=True,
              alpha=.8, zorder=1, size=6)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("../img/net_bin_str.eps")

# %%
# color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set2')
    
plt.figure(figsize=(10,10))
sns.boxplot( data=net_data, x="band", y='str_beta_num', hue='fc_measure')
sns.stripplot( data=net_data, x="band", y='str_beta_num',hue='fc_measure',color='black',jitter=True, dodge=True,
              alpha=.8, zorder=1, size=6)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("../img/net_num_str.eps")

# %% [markdown]
# Is it different within or outside of the SOZ?

# %%
# reshape data
soz_net_data_bin = pd.melt(net_data, id_vars =['band', 'fc_measure', 'subj'], value_vars =['str_soz_beta_bin','str_not_soz_beta_bin'],  var_name ='SOZ', value_name ='soz_beta_bin')  

#color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set2')
    
g = sns.FacetGrid(data=soz_net_data_bin, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'soz_beta_bin', 'SOZ')
g.map(sns.stripplot, 'band', 'soz_beta_bin', 'SOZ',jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
    
g.savefig("../img/net_soz_bin.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the stripplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# reshape data
soz_net_data_num = pd.melt(net_data, id_vars =['band', 'fc_measure', 'subj'], value_vars =['str_soz_beta_num','str_not_soz_beta_num'],  var_name ='SOZ', value_name ='soz_beta_num')  

#color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set1')
    
g = sns.FacetGrid(data=soz_net_data_num, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'soz_beta_num', 'SOZ')
g.map(sns.stripplot, 'band', 'soz_beta_num', 'SOZ',jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
    
g.savefig("../img/net_num.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the stripplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Repeat for spikes

# %%
# reshape data
spike_net_data_bin = pd.melt(net_data, id_vars =['band', 'fc_measure', 'subj'], value_vars =['str_spike_beta_bin','str_not_spike_beta_bin'],  var_name ='spike', value_name ='spike_beta_bin')  

#color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set2')
    
g = sns.FacetGrid(data=spike_net_data_bin, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'spike_beta_bin', 'spike')
g.map(sns.stripplot, 'band', 'spike_beta_bin', 'spike',jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
    
g.savefig("../img/net_spike_bin.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the stripplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# reshape data
spike_net_data_bin = pd.melt(net_data, id_vars =['band', 'fc_measure', 'subj'], value_vars =['str_spike_beta_num','str_not_spike_beta_num'],  var_name ='spike', value_name ='spike_beta_num')  

#color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set1')
    
g = sns.FacetGrid(data=spike_net_data_bin, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'spike_beta_num', 'spike')
g.map(sns.stripplot, 'band', 'spike_beta_num', 'spike',jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
    
g.savefig("../img/net_spike_num.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the boxplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:708: UserWarning: Using the stripplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Effects on Node Measures

# %%
#color pallette
colors = ['#5b6c88', '#f0eee2']
custom_palette = sns.set_palette('Set2')
    
g = sns.FacetGrid(data=soz_net_data_bin, col='fc_measure' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.scatterplot, 'elec_spike', 'str_beta_bin', 'band',jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-74a977cbc632> in <module>()
#       5 g = sns.FacetGrid(data=soz_net_data_bin, col='fc_measure' ,col_wrap = 2,
#       6                   sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
# ----> 7 g.map(sns.scatterplot, 'elec_spike', 'str_beta_bin', 'band',jitter=True, dodge=True,
#       8               alpha=.2, zorder=1, size=6)
#       9 g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=node_data, col='fc_measure', col_wrap = 3, 
                  sharex=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'str_beta_bin', 'elec_in_soz', hue_order = [0, 1])
g.map(sns.stripplot, 'band', 'str_beta_bin', 'elec_in_soz', hue_order = [0,1], jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# grand teton natl park color pallette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))
    
g = sns.FacetGrid(data=node_data, col='fc_measure', col_wrap = 3, 
                  sharex=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'band', 'str_beta_num', 'elec_in_soz', hue_order = [0, 1])
g.map(sns.stripplot, 'band', 'str_beta_num', 'elec_in_soz', hue_order = [0,1], jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### Categorize SOZ

# %%
temporal = ['lingual', 'bankssts', 'temp', 'hippo', 'rhin', 'fusiform']
frontal = ['front']

# %%
# check labels of elecs in soz. Mark as TLE if they contain temporal, 
# and FLE if frontal...for noww. would be better to have clinical 
# labels

epilepsy_type = pd.DataFrame(data={'subj':node_data.subj.unique(), 
                                   'locus':np.empty(node_data.subj.unique().shape)})
for index,row in epilepsy_type.iterrows():
    curr = node_data[node_data['subj'] == row.subj][node_data['elec_in_soz'] == 1]
    tle = [];
    fle = [];
    regions = curr.region.unique()
    for v in regions:
        if type(v) == str:
            tle.append(any([i in v for i in temporal]))
            fle.append(any([i in v for i in frontal]))
    if any(tle) and not any(fle):
        epilepsy_type.loc[index, 'locus'] = 'tle'
    elif any(fle) and not any(tle):
        epilepsy_type.loc[index, 'locus'] = 'fle'
    else:
        epilepsy_type.loc[index,'locus'] = 'amb'
    
epilepsy_type.head()
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      subj locus
# 0  R1284N   amb
# 1  R1276D   tle
# 2  R1260D   amb
# 3  R1250N   amb
# 4  R1247P   tle

# %%
sns.countplot(data=epilepsy_type, x='locus')

# %%
# add locus back to big data frames
net_data = pd.merge(net_data, epilepsy_type, on='subj')
node_data = pd.merge(node_data, epilepsy_type, on='subj')
net_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6356 entries, 0 to 6355
# Data columns (total 15 columns):
# band_measure    6356 non-null object
# soz             6356 non-null category
# n_tp            6356 non-null int64
# str_beta_bin    6356 non-null float64
# str_beta_num    6356 non-null float64
# fc_measure      6356 non-null object
# band            6356 non-null object
# subj            6356 non-null object
# hand            6356 non-null object
# age             6356 non-null float64
# gender          6356 non-null object
# race            6356 non-null float64
# locus_x         6356 non-null object
# locus_y         6356 non-null object
# locus           6356 non-null object
# dtypes: category(1), float64(4), int64(1), object(9)
# memory usage: 751.2+ KB

# %%
node_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209280 entries, 0 to 209279
# Data columns (total 27 columns):
# elec                      209280 non-null object
# band_measure              209280 non-null object
# n_tp                      209280 non-null int64
# elec_spike                209280 non-null float64
# elec_in_soz               209280 non-null int64
# str_soz_beta_bin          207728 non-null float64
# str_not_soz_beta_bin      192284 non-null float64
# str_spike_beta_bin        208608 non-null float64
# str_not_spike_beta_bin    171530 non-null float64
# str_beta_bin              208608 non-null float64
# str_soz_beta_num          207728 non-null float64
# str_not_soz_beta_num      192284 non-null float64
# str_spike_beta_num        208608 non-null float64
# str_beta_num              208608 non-null float64
# str_not_spike_beta_num    171530 non-null float64
# fc_measure                209280 non-null object
# band                      209280 non-null object
# region                    192448 non-null object
# x                         209280 non-null float64
# y                         209280 non-null float64
# z                         209280 non-null float64
# subj                      209280 non-null object
# hand                      209280 non-null object
# age                       209280 non-null float64
# gender                    209280 non-null object
# race                      209280 non-null float64
# locus                     209280 non-null object
# dtypes: float64(16), int64(2), object(9)
# memory usage: 44.7+ MB

# %% [markdown]
# ## Net plots with category by locus

# %%
#get only total strength
net_str = net_data[net_data['soz'] == 2]

# %%
# grand teton palette
colors = ['#a8d0cf', '#babbb1']
custom_palette = sns.set_palette(sns.color_palette(colors))

g = sns.FacetGrid(data=net_str, col='band' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'fc_measure', 'str_beta_bin', 'locus', hue_order = ['tle','fle','amb'])
g.map(sns.stripplot, 'fc_measure', 'str_beta_bin', 'locus', hue_order = ['tle','fle','amb'],jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-5,5)
    
#g.savefig("../img/net_num.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(data=net_str, col='band' ,col_wrap = 2, 
                  sharex=False, sharey=False, legend_out=True, palette = custom_palette, size=8)
g.map(sns.boxplot, 'fc_measure', 'str_beta_num', 'locus', hue_order = ['tle','fle','amb'])
g.map(sns.stripplot, 'fc_measure', 'str_beta_num', 'locus', hue_order = ['tle','fle','amb'],jitter=True, dodge=True,
              alpha=.2, zorder=1, size=6)
g.axes[0].set_xticklabels(g.axes[0].xaxis.get_majorticklabels(),rotation=30)
g.axes[1].set_xticklabels(g.axes[1].xaxis.get_majorticklabels(),rotation=30)
g.axes[2].set_xticklabels(g.axes[2].xaxis.get_majorticklabels(),rotation=30)
g.axes[4].legend(bbox_to_anchor = (1.05,1), loc=2, borderaxespad=0.)
#for ax in g.axes:
#    ax.set_ylim(-2,2)
    
#g.savefig("../img/net_num.eps")
# Out:
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /Users/stiso/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the stripplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
